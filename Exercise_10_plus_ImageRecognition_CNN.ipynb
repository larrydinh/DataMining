# %%
# --- Imports ---
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.utils import to_categorical

from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# --- Load CIFAR-10 ---
(num_classes, img_h, img_w, img_c) = (10, 32, 32, 3)
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

# Scale to [0,1]
x_train = x_train.astype("float32") / 255.0
x_test  = x_test.astype("float32") / 255.0

# Optional: standardize per-channel (helps convergence on CIFAR-10)
# Compute mean/std from training set only to avoid leakage
mean = x_train.mean(axis=(0,1,2), keepdims=True)
std  = x_train.std(axis=(0,1,2), keepdims=True) + 1e-7
x_train = (x_train - mean) / std
x_test  = (x_test  - mean) / std

# One-hot labels for training with categorical_crossentropy
y_train_cat = to_categorical(y_train, num_classes)
y_test_cat  = to_categorical(y_test, num_classes)

# Class names for nicer reporting
class_names = np.array([
    "airplane","automobile","bird","cat","deer",
    "dog","frog","horse","ship","truck"
])

# --- Model ---
model = Sequential([
    keras.Input(shape=(img_h, img_w, img_c)),

    Conv2D(32, 3, padding='same', activation='relu'),
    BatchNormalization(),
    Conv2D(32, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),

    Conv2D(64, 3, padding='same', activation='relu'),
    BatchNormalization(),
    Conv2D(64, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),

    GlobalAveragePooling2D(),
    Dense(128, activation='relu', kernel_regularizer=keras.regularizers.l2(1e-4)),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

opt = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

# --- Callbacks ---
callbacks = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-5, verbose=1),
    EarlyStopping(monitor='val_loss', patience=12, restore_best_weights=True, verbose=1),
]

# --- Train ---
history = model.fit(
    x_train, y_train_cat,
    validation_data=(x_test, y_test_cat),
    epochs=80,
    batch_size=128,
    callbacks=callbacks,
    verbose=1
)

# --- Evaluate ---
test_loss, test_acc = model.evaluate(x_test, y_test_cat, verbose=0)
print(f"\nTest accuracy: {test_acc:.4f}  |  Test loss: {test_loss:.4f}")

# --- Predictions for reports ---
y_prob = model.predict(x_test, verbose=0)
y_pred = np.argmax(y_prob, axis=1).reshape(-1)
y_true = y_test.reshape(-1)

# --- Classification report ---
print("\nClassification Report (per class):")
print(classification_report(y_true, y_pred, target_names=class_names, digits=4))

# --- Confusion matrix ---
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
fig, ax = plt.subplots(figsize=(8, 8))
disp.plot(ax=ax, xticks_rotation=45, cmap="Blues", colorbar=False)
ax.set_title("CIFAR-10 Confusion Matrix (CNN)")
plt.tight_layout()
plt.show()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 64)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 75,562 (295.16 KB)
#  Trainable params: 75,370 (294.41 KB)
#  Non-trainable params: 192 (768.00 B)
# Epoch 1/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 96ms/step - accuracy: 0.2714 - loss: 1.9545 - val_accuracy: 0.4112 - val_loss: 1.5753 - learning_rate: 0.0100
# Epoch 2/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.4571 - loss: 1.4893 - val_accuracy: 0.5165 - val_loss: 1.3398 - learning_rate: 0.0100
# Epoch 3/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.5268 - loss: 1.3135 - val_accuracy: 0.5346 - val_loss: 1.2773 - learning_rate: 0.0100
# Epoch 4/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.5708 - loss: 1.2077 - val_accuracy: 0.5416 - val_loss: 1.2579 - learning_rate: 0.0100
# Epoch 5/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.5929 - loss: 1.1496 - val_accuracy: 0.6239 - val_loss: 1.0539 - learning_rate: 0.0100
# Epoch 6/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 98ms/step - accuracy: 0.6114 - loss: 1.0952 - val_accuracy: 0.6368 - val_loss: 1.0415 - learning_rate: 0.0100
# Epoch 7/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.6313 - loss: 1.0477 - val_accuracy: 0.6504 - val_loss: 0.9803 - learning_rate: 0.0100
# Epoch 8/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 39s 99ms/step - accuracy: 0.6505 - loss: 0.9923 - val_accuracy: 0.6401 - val_loss: 1.0082 - learning_rate: 0.0100
# Epoch 9/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.6604 - loss: 0.9703 - val_accuracy: 0.6612 - val_loss: 0.9526 - learning_rate: 0.0100
# Epoch 10/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.6707 - loss: 0.9356 - val_accuracy: 0.6713 - val_loss: 0.9189 - learning_rate: 0.0100
# Epoch 11/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.6868 - loss: 0.8986 - val_accuracy: 0.6899 - val_loss: 0.8951 - learning_rate: 0.0100
# Epoch 12/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 98ms/step - accuracy: 0.6930 - loss: 0.8856 - val_accuracy: 0.6929 - val_loss: 0.8672 - learning_rate: 0.0100
# Epoch 13/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.7015 - loss: 0.8672 - val_accuracy: 0.7108 - val_loss: 0.8230 - learning_rate: 0.0100
# Epoch 14/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 98ms/step - accuracy: 0.7060 - loss: 0.8498 - val_accuracy: 0.7292 - val_loss: 0.7717 - learning_rate: 0.0100
# Epoch 15/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 96ms/step - accuracy: 0.7168 - loss: 0.8217 - val_accuracy: 0.7071 - val_loss: 0.8472 - learning_rate: 0.0100
# Epoch 16/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.7231 - loss: 0.8069 - val_accuracy: 0.7339 - val_loss: 0.7695 - learning_rate: 0.0100
# Epoch 17/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 98ms/step - accuracy: 0.7229 - loss: 0.8031 - val_accuracy: 0.7360 - val_loss: 0.7598 - learning_rate: 0.0100
# Epoch 18/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 98ms/step - accuracy: 0.7330 - loss: 0.7792 - val_accuracy: 0.7274 - val_loss: 0.7803 - learning_rate: 0.0100
# Epoch 19/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 98ms/step - accuracy: 0.7404 - loss: 0.7662 - val_accuracy: 0.7351 - val_loss: 0.7568 - learning_rate: 0.0100
# Epoch 20/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 39s 99ms/step - accuracy: 0.7404 - loss: 0.7586 - val_accuracy: 0.7481 - val_loss: 0.7406 - learning_rate: 0.0100
# Epoch 21/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.7460 - loss: 0.7442 - val_accuracy: 0.7538 - val_loss: 0.7190 - learning_rate: 0.0100
# Epoch 22/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 98ms/step - accuracy: 0.7510 - loss: 0.7295 - val_accuracy: 0.7321 - val_loss: 0.7752 - learning_rate: 0.0100
# Epoch 23/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.7497 - loss: 0.7248 - val_accuracy: 0.7501 - val_loss: 0.7353 - learning_rate: 0.0100
# Epoch 24/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 98ms/step - accuracy: 0.7582 - loss: 0.7098 - val_accuracy: 0.7399 - val_loss: 0.7786 - learning_rate: 0.0100
# Epoch 25/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 98ms/step - accuracy: 0.7617 - loss: 0.7021 - val_accuracy: 0.7593 - val_loss: 0.6944 - learning_rate: 0.0100
# Epoch 26/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 98ms/step - accuracy: 0.7683 - loss: 0.6815 - val_accuracy: 0.7643 - val_loss: 0.6889 - learning_rate: 0.0100
# Epoch 27/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.7654 - loss: 0.6871 - val_accuracy: 0.7643 - val_loss: 0.6892 - learning_rate: 0.0100
# Epoch 28/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 39s 98ms/step - accuracy: 0.7721 - loss: 0.6716 - val_accuracy: 0.7587 - val_loss: 0.7198 - learning_rate: 0.0100
# Epoch 29/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 39s 100ms/step - accuracy: 0.7794 - loss: 0.6551 - val_accuracy: 0.7769 - val_loss: 0.6558 - learning_rate: 0.0100
# Epoch 30/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.7744 - loss: 0.6650 - val_accuracy: 0.7674 - val_loss: 0.6817 - learning_rate: 0.0100
# Epoch 31/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.7771 - loss: 0.6535 - val_accuracy: 0.7700 - val_loss: 0.6785 - learning_rate: 0.0100
# Epoch 32/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.7836 - loss: 0.6416 - val_accuracy: 0.7768 - val_loss: 0.6594 - learning_rate: 0.0100
# Epoch 33/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 98ms/step - accuracy: 0.7859 - loss: 0.6359 - val_accuracy: 0.7778 - val_loss: 0.6470 - learning_rate: 0.0100
# Epoch 34/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 96ms/step - accuracy: 0.7888 - loss: 0.6256 - val_accuracy: 0.7534 - val_loss: 0.7267 - learning_rate: 0.0100
# Epoch 35/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 96ms/step - accuracy: 0.7884 - loss: 0.6260 - val_accuracy: 0.7911 - val_loss: 0.6136 - learning_rate: 0.0100
# Epoch 36/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.7897 - loss: 0.6210 - val_accuracy: 0.7831 - val_loss: 0.6342 - learning_rate: 0.0100
# Epoch 37/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.7921 - loss: 0.6195 - val_accuracy: 0.7746 - val_loss: 0.6595 - learning_rate: 0.0100
# Epoch 38/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 98ms/step - accuracy: 0.7945 - loss: 0.6086 - val_accuracy: 0.7783 - val_loss: 0.6703 - learning_rate: 0.0100
# Epoch 39/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 98ms/step - accuracy: 0.7959 - loss: 0.6052 - val_accuracy: 0.7778 - val_loss: 0.6589 - learning_rate: 0.0100
# Epoch 40/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.7978 - loss: 0.5941
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.7978 - loss: 0.5941 - val_accuracy: 0.7901 - val_loss: 0.6321 - learning_rate: 0.0100
# Epoch 41/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 98ms/step - accuracy: 0.8075 - loss: 0.5754 - val_accuracy: 0.7959 - val_loss: 0.6060 - learning_rate: 0.0050
# Epoch 42/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.8127 - loss: 0.5565 - val_accuracy: 0.7996 - val_loss: 0.5972 - learning_rate: 0.0050
# Epoch 43/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.8129 - loss: 0.5541 - val_accuracy: 0.7993 - val_loss: 0.5968 - learning_rate: 0.0050
# Epoch 44/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.8166 - loss: 0.5474 - val_accuracy: 0.8057 - val_loss: 0.5859 - learning_rate: 0.0050
# Epoch 45/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 98ms/step - accuracy: 0.8180 - loss: 0.5443 - val_accuracy: 0.8054 - val_loss: 0.5743 - learning_rate: 0.0050
# Epoch 46/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 98ms/step - accuracy: 0.8154 - loss: 0.5462 - val_accuracy: 0.8076 - val_loss: 0.5942 - learning_rate: 0.0050
# Epoch 47/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 98ms/step - accuracy: 0.8185 - loss: 0.5455 - val_accuracy: 0.7978 - val_loss: 0.6140 - learning_rate: 0.0050
# Epoch 48/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.8197 - loss: 0.5456 - val_accuracy: 0.8086 - val_loss: 0.5707 - learning_rate: 0.0050
# Epoch 49/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 98ms/step - accuracy: 0.8217 - loss: 0.5370 - val_accuracy: 0.8111 - val_loss: 0.5831 - learning_rate: 0.0050
# Epoch 50/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 37s 96ms/step - accuracy: 0.8239 - loss: 0.5240 - val_accuracy: 0.8069 - val_loss: 0.5788 - learning_rate: 0.0050
# Epoch 51/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.8229 - loss: 0.5329 - val_accuracy: 0.8155 - val_loss: 0.5725 - learning_rate: 0.0050
# Epoch 52/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.8230 - loss: 0.5276 - val_accuracy: 0.8065 - val_loss: 0.5877 - learning_rate: 0.0050
# Epoch 53/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8205 - loss: 0.5367
# Epoch 53: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.8205 - loss: 0.5367 - val_accuracy: 0.8053 - val_loss: 0.5890 - learning_rate: 0.0050
# Epoch 54/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 98ms/step - accuracy: 0.8268 - loss: 0.5105 - val_accuracy: 0.8114 - val_loss: 0.5667 - learning_rate: 0.0025
# Epoch 55/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.8316 - loss: 0.4993 - val_accuracy: 0.8121 - val_loss: 0.5652 - learning_rate: 0.0025
# Epoch 56/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.8317 - loss: 0.5061 - val_accuracy: 0.8194 - val_loss: 0.5493 - learning_rate: 0.0025
# Epoch 57/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 39s 99ms/step - accuracy: 0.8321 - loss: 0.5009 - val_accuracy: 0.8102 - val_loss: 0.5810 - learning_rate: 0.0025
# Epoch 58/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 98ms/step - accuracy: 0.8350 - loss: 0.4980 - val_accuracy: 0.8113 - val_loss: 0.5768 - learning_rate: 0.0025
# Epoch 59/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 98ms/step - accuracy: 0.8307 - loss: 0.5008 - val_accuracy: 0.8078 - val_loss: 0.5779 - learning_rate: 0.0025
# Epoch 60/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 98ms/step - accuracy: 0.8352 - loss: 0.4926 - val_accuracy: 0.8074 - val_loss: 0.5957 - learning_rate: 0.0025
# Epoch 61/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8319 - loss: 0.5011
# Epoch 61: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.8320 - loss: 0.5011 - val_accuracy: 0.8126 - val_loss: 0.5715 - learning_rate: 0.0025
# Epoch 62/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 96ms/step - accuracy: 0.8383 - loss: 0.4851 - val_accuracy: 0.8161 - val_loss: 0.5615 - learning_rate: 0.0012
# Epoch 63/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.8386 - loss: 0.4863 - val_accuracy: 0.8149 - val_loss: 0.5672 - learning_rate: 0.0012
# Epoch 64/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.8386 - loss: 0.4808 - val_accuracy: 0.8198 - val_loss: 0.5481 - learning_rate: 0.0012
# Epoch 65/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 98ms/step - accuracy: 0.8381 - loss: 0.4831 - val_accuracy: 0.8186 - val_loss: 0.5537 - learning_rate: 0.0012
# Epoch 66/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 96ms/step - accuracy: 0.8399 - loss: 0.4828 - val_accuracy: 0.8179 - val_loss: 0.5621 - learning_rate: 0.0012
# Epoch 67/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 98ms/step - accuracy: 0.8394 - loss: 0.4749 - val_accuracy: 0.8182 - val_loss: 0.5581 - learning_rate: 0.0012
# Epoch 68/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.8369 - loss: 0.4881 - val_accuracy: 0.8209 - val_loss: 0.5523 - learning_rate: 0.0012
# Epoch 69/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.8424 - loss: 0.4672 - val_accuracy: 0.8216 - val_loss: 0.5451 - learning_rate: 0.0012
# Epoch 70/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 98ms/step - accuracy: 0.8389 - loss: 0.4754 - val_accuracy: 0.8204 - val_loss: 0.5500 - learning_rate: 0.0012
# Epoch 71/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 39s 100ms/step - accuracy: 0.8422 - loss: 0.4701 - val_accuracy: 0.8113 - val_loss: 0.5774 - learning_rate: 0.0012
# Epoch 72/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 98ms/step - accuracy: 0.8424 - loss: 0.4717 - val_accuracy: 0.8154 - val_loss: 0.5556 - learning_rate: 0.0012
# Epoch 73/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 39s 99ms/step - accuracy: 0.8405 - loss: 0.4732 - val_accuracy: 0.8203 - val_loss: 0.5494 - learning_rate: 0.0012
# Epoch 74/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8431 - loss: 0.4699
# Epoch 74: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 98ms/step - accuracy: 0.8431 - loss: 0.4700 - val_accuracy: 0.8217 - val_loss: 0.5452 - learning_rate: 0.0012
# Epoch 75/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 39s 99ms/step - accuracy: 0.8435 - loss: 0.4708 - val_accuracy: 0.8173 - val_loss: 0.5552 - learning_rate: 6.2500e-04
# Epoch 76/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 39s 100ms/step - accuracy: 0.8446 - loss: 0.4627 - val_accuracy: 0.8204 - val_loss: 0.5499 - learning_rate: 6.2500e-04
# Epoch 77/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 39s 100ms/step - accuracy: 0.8418 - loss: 0.4658 - val_accuracy: 0.8195 - val_loss: 0.5471 - learning_rate: 6.2500e-04
# Epoch 78/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 39s 99ms/step - accuracy: 0.8440 - loss: 0.4697 - val_accuracy: 0.8189 - val_loss: 0.5464 - learning_rate: 6.2500e-04
# Epoch 79/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.8415 - loss: 0.4718
# Epoch 79: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 39s 100ms/step - accuracy: 0.8415 - loss: 0.4718 - val_accuracy: 0.8191 - val_loss: 0.5474 - learning_rate: 6.2500e-04
# Epoch 80/80
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 98ms/step - accuracy: 0.8450 - loss: 0.4662 - val_accuracy: 0.8182 - val_loss: 0.5520 - learning_rate: 3.1250e-04
# Restoring model weights from the end of the best epoch: 69.
#
# Test accuracy: 0.8216  |  Test loss: 0.5451
#
# Classification Report (per class):
#               precision    recall  f1-score   support
#
#     airplane     0.8263    0.8420    0.8341      1000
#   automobile     0.9385    0.8850    0.9110      1000
#         bird     0.7567    0.7310    0.7436      1000
#          cat     0.7167    0.6400    0.6762      1000
#         deer     0.7723    0.8310    0.8006      1000
#          dog     0.7253    0.7710    0.7475      1000
#         frog     0.8230    0.8790    0.8501      1000
#        horse     0.9023    0.8130    0.8553      1000
#         ship     0.8649    0.9280    0.8953      1000
#        truck     0.8978    0.8960    0.8969      1000
#
#     accuracy                         0.8216     10000
#    macro avg     0.8224    0.8216    0.8211     10000
# weighted avg     0.8224    0.8216    0.8211     10000
